# %% [markdown]
# ### Read Sheet 2

# %%
import pandas as pd
import numpy as np

# Define cols to fetch
cols = ["Fake Applicant ID", "Age (Birthday Masked)", "Income", "Promise Zone?", "Primary Interest In Course", "Education", "Hours Coded", "How Many Hours A Week Can You Commit To Class", "Hacker Rank Score", "Completed?"]
# Get app data
df_sheet2_filt = pd.read_csv("https://s3-eu-west-1.amazonaws.com/ai-hack-q3-orion/datasets/app_demo_data.csv",
                 skip_blank_lines=True,
                 index_col=0,
                 na_values='No Data',
                 usecols=cols
                )
df_sheet2_filt.head()
# Out:
#                    Age (Birthday Masked)              Income     Education  \
# Fake Applicant ID
# 58123                                 54  $90,000 - $100,000      Master's
# 35033                                 30   $10,000 - $20,000  Some college
# 24480                                 27   $20,000 - $30,000  Some college
# 64235                                 36   $50,000 - $60,000      Master's
# 35425                                 59    Less than $5,000  Some college
#
#                    Promise Zone?  \
# Fake Applicant ID
# 58123                          0
# 35033                          0
# 24480                          0
# 64235                          0
# 35425                          0
#
#                                           Primary Interest In Course  \
# Fake Applicant ID
# 58123              Interested in seeking an apprenticeship/job in...
# 35033              Interested in seeking an apprenticeship/job in...
# 24480              Interested in seeking an apprenticeship/job in...
# 64235              Interested in seeking an apprenticeship/job in...
# 35425              Interested in seeking an apprenticeship/job in...
#
#                   Hours Coded How Many Hours A Week Can You Commit To Class  \
# Fake Applicant ID
# 58123                    6-50                                         21-40
# 35033                    250+                                         21-40
# 24480                     0-5                                         21-40
# 64235                    6-50                                         21-40
# 35425                    6-50                                         21-40
#
#                    Hacker Rank Score  Completed?
# Fake Applicant ID
# 58123                            8.7           0
# 35033                            8.0           0
# 24480                            8.7           0
# 64235                            8.0           0
# 35425                            0.0           0

# %%
df_sheet2_filt.groupby('Fake Applicant ID')['Age (Birthday Masked)']..head()
# Out:
# Fake Applicant ID
# 10047    30.0
# 10124    45.0
# 10197    50.0
# 10204    48.0
# 10232    44.0
# Name: Age (Birthday Masked), dtype: float64

# %% [markdown]
# ### Read sheet 1

# %%
# Define cols to fetch
cols = ["Fake Applicant ID", "Attendance", "Course Id"]
# Get completion data
df_sheet1 = pd.read_csv("https://s3-eu-west-1.amazonaws.com/ai-hack-q3-orion/datasets/completion_data.csv", 
                 skip_blank_lines=True,
                 index_col=1,
                 na_values='No Data',
                 usecols=cols,
                 dtype = {"Course Id" : "object", "Fake Applicant ID" : "int32", "Attendance" : "str"}
                )
df_sheet1_filt = df_sheet1.dropna(axis=0)
df_sheet1_filt.head()
# Out:
#                   Course Id Attendance
# Fake Applicant ID
# 10124                    77   Attended
# 10124                    77   Attended
# 10124                    77   Attended
# 10124                    77   Attended
# 10124                    77   Attended

# %%
df_sheet1_filt.groupby('Fake Applicant ID')['Attendance'].mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-44-006ae897f207> in <module>()
# ----> 1 df_sheet1_filt.groupby('Fake Applicant ID')['Attendance'].mean()
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1130         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1131         try:
# -> 1132             return self._cython_agg_general('mean', **kwargs)
#    1133         except GroupByError:
#    1134             raise
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     836
#     837         if len(output) == 0:
# --> 838             raise DataError('No numeric types to aggregate')
#     839
#     840         return self._wrap_aggregated_output(output, names)
#
# DataError: No numeric types to aggregate
